# %% [markdown]
# # Seaborn
# https://www.kaggle.com/jchen2186/machine-learning-with-iris-dataset

# %% [markdown]
# ## Paramter
# * Palette = Farbselektion
# * hue = Subselection
# * markers = Figuren
# * corner = Bei Pairplots wird nur die Hälfte dargestellt

# %%
# Bibs
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# load data
advertising=pd.read_csv('./Sample-Projects/ISLR/data/islrData_advertising.csv',delimiter=',',encoding='utf-8')
advertising = advertising.drop(['Unnamed: 0'], axis=1)

# %% [markdown]
# ## Grundlagen Scatterplot

# %% [markdown]
# ### Single-Plot

# %%
sns.scatterplot(x=advertising.TV, y=advertising.sales, data=advertising) # so wird die grafik direkt ausgegeben
var = sns.scatterplot(x=advertising.TV, y=advertising.sales, data=advertising) # jetzt ist die Grafik in der Varibale Test
# hinterlegt und kann dann bspw in mehreren Plots dargesteltl werden

# %% [markdown]
# ### Multiplot

# %%
cols = ['TV','radio','newspaper']
fig,axes = plt.subplots(1,3,figsize=(20,6))
for seg,col in enumerate(cols):
    x,y = seg//3,seg%3
    an=sns.scatterplot(x=col, y='sales' ,data=advertising, ax=axes[y])
    plt.setp(an.get_xticklabels(), rotation=45)

# %% [markdown]
# ## Verteilungen

# %%
print(test)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# ## grundlagen Regressionplot(basis Scatterplot)

# %%
sns.regplot(advertising.TV, advertising.sales, order=1, ci=None, scatter_kws={'color':'r', 's':9})
plt.xlim(-10,310)
plt.ylim(ymin=0);

# %% [markdown]
# ## Distributions

# %%
plt.figure(figsize=(8,8))
plt.title('Sales Distribution Plot')
sns.distplot(advertising[['sales']])

# %% [markdown]
# ## Pairplots

# %%
sns.pairplot(advertising)

# %% [markdown]
# Insight: TV scheint einen linearen Zusammenhang zu sales haben

# %% [markdown]
# ## Heatmap

# %%
plt.figure(figsize = (10, 8))
df_corr = advertising.corr()
ax = sns.heatmap(df_corr, annot=True, cmap="RdYlGn") 
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (4.5, -0.5)
