# %% [markdown]
# <h1>Kapitel 2 | Print-Statement</h1>
# <p>Dieses Kapitel dient der ersten Berührung mit der Sprache und dem erlernen von ausgaben</p>
# <p>Wenn man bereits eine Programmiersprache beherrscht kann hier schnell drüber gehoppt werden</p>
#
# <table>
#   <tr>
#     <th>Python-Lösung</th>
#     <th>Aufgabe</th>
#     <th>Beschreibung</th>
#   </tr>
#
#  <tr>
#      <td><a href="./Kapitel2/Aufgabe_1.ipynb">Aufgabe 1</a></td>
#      <td>Raketenstart / Hello world</td>
#      <td>erste Print ausgabe</td>
#    </tr>
#
#    <tr>
#      <td><a href="./Kapitel2/Aufgabe_2.ipynb">Aufgabe 2</a></td>
#      <td>Weihnachtsbaum</td>
#      <td>Ausgabe von ersten Figuren </td>
#    </tr>
#
#    <tr>
#      <td><a href="./Kapitel2/Aufgabe_3.ipynb">Aufgabe 3</a></td>
#      <td>Perlenkette</td>
#      <td>Vorbereitung für Schleifen </td>
#    </tr>
#
#    <tr>
#      <td><a href="./Kapitel2/Aufgabe_4.ipynb">Aufgabe 4</a></td>
#      <td>Die erste Zeichnung</td>
#      <td>print unterschiedliche Formen </td>
#    </tr>
#
#    <tr>
#      <td><a href="./Kapitel2/Aufgabe_5.ipynb">Aufgabe 5</a></td>
#      <td>Raupe</td>
#      <td>Ausgabe von ersten Figuren </td>
#    </tr>
#
#    <tr>
#      <td><a href="./Kapitel2/Aufgabe_6.ipynb">Aufgabe 6</a></td>
#      <td>Klötzchen-Kunst</td>
#      <td>Figur </td>
#    </tr>
#
#    <tr>
#      <td><a href="./Kapitel2/Aufgabe_7.ipynb">Aufgabe 7</a></td>
#      <td>Eule</td>
#      <td>Shapes</td>
#    </tr>
#
#    <tr>
#      <td><a href="./Kapitel2/Aufgabe_8.ipynb">Aufgabe 8</a></td>
#      <td>Ghettoblaster</td>
#      <td>Figuren </td>
#    </tr>
#
#    <tr>
#      <td><a href="./Kapitel2/Aufgabe_9.ipynb">Aufgabe 9</a></td>
#      <td>Hello Bello</td>
#      <td>Figuren </td>
#    </tr>
#
#
# </table>

# %% [markdown]
# <h1>Kapitel 3 | Variablen, Datentype, Operatoren, Ausdrücke</h1>

# %% [markdown]
# <h1>Kapitel 4 | Kontrollstrukturen | If-Verzweigung</h1>

# %% [markdown]
# <h1>Kapitel 5 | Funktionen </h1>

# %% [markdown]
# <h1>Kapitel 6 | Array/List/Tupel/Set/Dictionary</h1>
# <p>Hier gehts um Arrays // java </p>
# <p> in Python sind arrays aufgeteilti in:
#     <ul>
#         <li>tupel</li>
#         <li>list</li>
#         <li>set</li>
#         <li>dictionary</li>
#         </ul>
#
# <table>
#   <tr>
#     <th>Python-Lösung</th>
#     <th>Aufgabe</th>
#     <th>Beschreibung</th>
#   </tr>
#
# <tr>
#     <td><a href="./Kapitel6/Aufgabe_01.ipynb">Aufgabe 1</a></td>
#     <td>Wochentags-Rechner</td>
#     <td>
#      <ul>
#          <li>Liste</li>
#          <li>Iterreiere loope über Liste</li>
#          <li>Mean</li>
#      </ul>
#    </td>
# </tr>
#
#
# <tr>
#     <td><a href="./Kapitel6/Aufgabe_02.ipynb">Aufgabe 2</a></td>
#     <td>Tankfüllung</td>
#     <td>
#      <ul>
#          <li>Modulo</li>
#          <li>Funktionsaufruf</li>
#          <li>Liste</li>
#      </ul>
#    </td>
# </tr>
#
# <tr>
#     <td><a href="./Kapitel6/Aufgabe_03.ipynb">Aufgabe 3</a></td>
#     <td>Rückwärtsausgabe</td>
#     <td>
#      <ul>
#          <li>String Rückwärts ausgeben</li>
#          <li>Funktionsaufruf</li>
#      </ul>
#    </td>
# </tr>
#
# <tr>
#     <td><a href="./Kapitel6/Aufgabe_04.ipynb">Aufgabe 4</a></td>
#     <td>Bildvergrößerung</td>
#     <td>
#      <ul>
#          <li>plotten der Array</li>
#          <li>eingabe Bild um faktor vergrößern</li>
#      </ul>
#    </td>
# </tr>
#
#
# <tr>
#     <td><a href="./Kapitel6/Aufgabe_05.ipynb">Aufgabe 5</a></td>
#     <td>Partnervermittlung</td>
#     <td>
#      <ul>
#          <b>PYTHON: </b>
#              <li>Vergleich von zweier listen</li>
#              <li>eingabe Bild um faktor vergrößern</li>
#      </ul>
#    </td>
# </tr>
#
# <tr>
#     <td><a href="./Kapitel6/Aufgabe_06.ipynb">Aufgabe 6</a></td>
#     <td>Sitzplatzreservierung</td>
#     <td>
#      <ul>
#          <b>PYTHON: </b>
#              <li>PrintAusgabe mittels # und _</li>
#              <li>For Schleife mit range </li>
#      </ul>
#    </td>
# </tr>
#
#
# <tr>
#     <td><a href="./Kapitel6/Aufgabe_07.ipynb">Aufgabe 7</a></td>
#     <td>Platztausch</td>
#     <td>
#      <ul>
#          <b>PYTHON: </b>
#              <li>Rückwärtsausgabe</li>
#
#    </ul>
#    </td>
# </tr>
#
#
# <tr>
#     <td><a href="./Kapitel6/Aufgabe_08.ipynb">Aufgabe 8</a></td>
#     <td>Bestimmung Minimale Distanz</td>
#     <td>
#      <ul>
#          <b>PYTHON: </b>
#              <li>Punktdistanz über eine dimension // nicht 2, das wäre Aufgabe 18 // wäre dann Koordinatensystem</li>
#              <li>Loop über alle Punkte hinweg</li>
#
#    </ul>
#    </td>
# </tr>
#
# <tr>
#     <td><a href="./Kapitel6/Aufgabe_09.ipynb">Aufgabe 9</a></td>
#     <td>Morsecode</td>
#     <td>
#      <ul>
#          <b>PYTHON: </b>
#              <li>Dictionary</li>
#              <li>Chifrieren</li>
#              <li>Dechifrieren</li>
#              <li>regex || split</li>
#
#
#    </ul>
#    </td>
# </tr>
#
# <tr>
#     <td><a href="./Kapitel6/Aufgabe_10.ipynb">Aufgabe 10</a></td>
#     <td>Animation</td>
#     <td>
#      <ul>
#          <b>PYTHON: </b>
#              <li>Picture Loop</li>
#
#    </ul>
#    </td>
# </tr>
#
# <tr>
#     <td><a href="./Kapitel6/Aufgabe_11.ipynb">Aufgabe 11</a></td>
#     <td>Bild Spiegeln</td>
#     <td>
#      <ul>
#          <b>PYTHON: </b>
#              <li>Plot-Functino</li>
#              <li>Entwurf der eigenen MNIST</li>
#
#    </ul>
#    </td>
# </tr>
#
# <tr>
#     <td><a href="./Kapitel6/Aufgabe_12.ipynb">Aufgabe 12</a></td>
#     <td>Bild Reflexion</td>
#     <td>
#      <ul>
#          <b>PYTHON: </b>
#              <li>Plot-to-Console-Function</li>
#              <li>unteren Zeilen Verlängern</li>
#
#    </ul>
#    </td>
# </tr>
#
# <tr>
#     <td><a href="./Kapitel6/Aufgabe_13.ipynb">Aufgabe 13</a></td>
#     <td>Greenscreen</td>
#     <td>
#      <ul>
#          <b>PYTHON: </b>
#              <li>zwei Lists übereinanderlegen</li>
#              <li>unteren Zeilen Verlängern</li>
#              <li>Rudimentäre Grundlage vom Green-Screen</li>
#
#    </ul>
#    </td>
# </tr>
#
# <tr>
#     <td><a href="./Kapitel6/Aufgabe_14.ipynb">Aufgabe 14</a></td>
#     <td>Bild drehen und Invertieren</td>
#     <td>
#      <ul>
#          <b>PYTHON: </b>
#              <li>Bild drehen um 180°</li>
#               <li>farben / Inhalt tauschen</li>
#
#
#    </ul>
#    </td>
# </tr>
#
# <tr>
#     <td><a href="./Kapitel6/Aufgabe_15.ipynb">Aufgabe 15</a></td>
#     <td>Bild mit Schatten</td>
#     <td>
#      <ul>
#          <b>PYTHON: </b>
#              <li>Schlagschatten zu Bild hinzufügen</li>
#
#    </ul>
#    </td>
# </tr>
#
# <tr>
#     <td><a href="./Kapitel6/Aufgabe_16.ipynb">Aufgabe 16</a></td>
#     <td>Bild rotieren</td>
#     <td>
#      <ul>
#          <b>PYTHON: </b>
#              <li>bild um 90° drehen</li>
#
#    </ul>
#    </td>
# </tr>
#
# <tr>
#     <td><a href="./Kapitel6/Aufgabe_17.ipynb">Aufgabe 17</a></td>
#     <td>Bild verkleinerung</td>
#     <td>
#      <ul>
#          <b>PYTHON: </b>
#              <li>Bild verkleinern anhand von Subbilder</li>
#
#    </ul>
#    </td>
# </tr>
#
# <tr>
#     <td><a href="./Kapitel6/Aufgabe_18.ipynb">Aufgabe 18</a></td>
#     <td>Minimale Punktdistanz</td>
#     <td>
#      <ul>
#          <b>PYTHON: </b>
#              <li>Punktdistanz im Koordinatensystem // vgl Aufgabe 08</li>
#               <li>Koordinaten einlesen</li>
#              <li>Distanz berechnen</li>
#
#    </ul>
#    </td>
# </tr>
#
#
# <tr>
#     <td><a href="./Kapitel6/Aufgabe_19.ipynb">Aufgabe 19</a></td>
#     <td>Glatte Kurven</td>
#     <td>
#      <ul>
#          <b>PYTHON: </b>
#              <li>glaetten einer gegebenen Liste</li>
#
#
#    </ul>
#    </td>
# </tr>
#
# <tr>
#     <td><a href="./Kapitel6/Aufgabe_20.ipynb">Aufgabe 20</a></td>
#     <td>Bildausschnitt</td>
#     <td>
#      <ul>
#          <b>PYTHON: </b>
#              <li>gebe aus einem großen Bild einen gewünschten Ausschnitt zurück</li>
#
#
#    </ul>
#    </td>
# </tr>
#
#
# <tr>
#     <td><a href="./Kapitel6/Aufgabe_21.ipynb">Aufgabe 21</a></td>
#     <td>Bild mit Rahmen</td>
#     <td>
#      <ul>
#          <b>PYTHON: </b>
#              <li>Umrande ein gegebenes Bild</li>
#
#
#    </ul>
#    </td>
# </tr>
#
#
# <tr>
#     <td><a href="./Kapitel6/Aufgabe_22.ipynb">Aufgabe 22</a></td>
#     <td>Memory-Spielfeldgenerator</td>
#     <td>
#      <ul>
#          <b>PYTHON: </b>
#              <li>Create Spielfeld</li>
#              <li>nur Spielfeld, kein tatsächliches Game</li>
#               <li>Random-Function</li>
#
#
#    </ul>
#    </td>
# </tr>
#
# <tr>
#     <td><a href="./Kapitel6/Aufgabe_23.ipynb">Aufgabe 23</a></td>
#     <td>Sudoku Checker</td>
#     <td>
#      <ul>
#          <b>PYTHON: </b>
#              <li>Prüfung für ausgefüllte Sudokus</li>
#           <li>Prüfung Zeile</li>
#           <li>Prüfung Spalte</li>
#           <li>Prüfung Block</li>
#
#
#
#    </ul>
#    </td>
# </tr>
#
# <tr>
#     <td><a href="./Kapitel6/Aufgabe_24.ipynb">Aufgabe 24</a></td>
#     <td>Bild-Korrektur</td>
#     <td>
#      <ul>
#          <b>PYTHON: </b>
#              <li>Bild Korrektur mit Mean der Umgegbungspixel</li>
#
#
#
#
#    </ul>
#    </td>
# </tr>
#
#
#
#
#
#
#
#
#
# </table>

# %% [markdown]
# <h1>Kapitel 7 |  Strings und Stringverarbeitung</h1>
#
# <p> hier ist es vlcht sinnvoller sich zunächst mit den <a href="https://github.com/JHC90/RegularExpressionsInPython">RegEx</a> zu beschäftigen. Hier kann ich nur öffnen wenn ich eingeloggt bin. <p>
#
# <table>
#   <tr>
#     <th>Python-Lösung</th>
#     <th>Aufgabe</th>
#     <th>Beschreibung</th>
#   </tr>
#
# <tr>
#     <td><a href="./Kapitel7/Aufgabe_01.ipynb">Aufgabe 1</a></td>
#     <td> String-Kompression</td>
#     <td>
#      <ul>
#           <b>PYTHON: </b>
#              <li>Zeichen zählen</li>
#          <li>String-Concatination</li>
#      </ul>
#    </td>
# </tr>
#
#
# <tr>
#     <td><a href="./Kapitel7/Aufgabe_02.ipynb">Aufgabe 2</a></td>
#     <td>Split-Function</td>
#     <td>
#      <ul>
#           <b>PYTHON: </b>
#              <li>RegexAufteilung</li>
#       </ul>
#    </td>
# </tr>
#
# <tr>
#     <td><a href="./Kapitel7/Aufgabe_03.ipynb">Aufgabe 3</a></td>
#     <td>  Geldschein-Blütencheck</td>
#     <td>
#      <ul>
#           <b>PYTHON: </b>
#              <li>Alpha-Numerisch Dictionary</li>
#              <li>Alphabet-Zahl-Dictionary</li>
#              <li>Alphabet-Zahl-Dictionary</li>
#           <li>String-Prüfungen</li>
#
#
#    </ul>
#    </td>
# </tr>
#
# <tr>
#     <td><a href="./Kapitel7/Aufgabe_04.ipynb">Aufgabe 4</a></td>
#     <td>Starkes Passwort</td>
#     <td>
#      <ul>
#           <b>PYTHON: </b>
#              <li>Regex</li>
#          <li>Prüfung mit Regex ob Muster in String und Boolean</li>
#              <li>Großbuchstaben </li>
#              <li>Kleibuchstabe</li>
#           <li>Ziffern</li>
#          <li>Sonderzeichen</li>
#          <li>Mindestlänge</li>
#          <li>Loop über die Testfälle</li>
#
#
#    </ul>
#    </td>
# </tr>
#
# <tr>
#     <td><a href="./Kapitel7/Aufgabe_05.ipynb">Aufgabe 5</a></td>
#     <td> E-Mail-Checkt</td>
#     <td>
#      <ul>
#           <b>PYTHON: </b>
#              <li>Regex</li>
#              <li>Prüfung ob String Boolean </li>
#              <li>if(bool(re.search(**********</li>
#              <li>Regex Bedingungen Verknüpfung</li>
#    </ul>
#    </td>
# </tr>
#
# <tr>
#     <td><a href="./Kapitel7/Aufgabe_06.ipynb">Aufgabe 6</a></td>
#     <td> Prüfen auf korrekte Klammerung</td>
#     <td>
#      <ul>
#           <b>PYTHON: </b>
#              <li>If-VVerzweigung auf String</li>
#              <li>Iteration durch String</li>
#              <li>Counter-Variable die nicht 0 unterschreiten darf</li>
#
#    </ul>
#    </td>
# </tr>
#
# <tr>
#     <td><a href="./Kapitel7/Aufgabe_07.ipynb">Aufgabe 7</a></td>
#     <td>Sternchenmuster</td>
#     <td>
#      <ul>
#           <b>PYTHON: </b>
#              <li>Usereingabe</li>
#              <li>String-Concatination</li>
#              <li>Test-List mit Loop über ausgabe</li>
#
#    </ul>
#    </td>
# </tr>
#
#
#
#
#
# </table>

# %% [markdown]
# <h1>Kapitel 8 |  Objektorientierung</h1>

# %% [markdown]
# <h1>Kapitel 9 |   Referenzdatentypen</h1>

# %% [markdown]
# <h1>Kapitel 10 |   Vererbung</h1>
