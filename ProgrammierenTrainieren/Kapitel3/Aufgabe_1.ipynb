# %%
from IPython.display import display, Image
display(Image(filename='./imgs/Aufgabe1.png'))

# %%
print(1 + 7 - 9 + 43)
# Out:
# 42

# %%
 print(12 % 2)
# Out:
# 0

# %%
 print(12 % 3)
# Out:
# 0

# %%
 print(12 % 4)
# Out:
# 0

# %%
 print(12 % 5)
# Out:
# 2
