# %%
from IPython.display import display, Image
display(Image(filename='./imgs/Aufgabe2.png'))

# %% [markdown]
# Hier greife ich auf das tasächliche Programm zurück, da ich jetzt keinen Bock hab das in Python Grafik anfang modul zu suchen.
#
# Installation von:
#
# https://processing.org/download/
#
#
# und dort dann noch das Python Modul zusätzlich installieren:

# %%
display(Image(filename='./imgs/0InstallPython.png'))

# %% [markdown]
# hier die lösung für dieses File:

# %%
display(Image(filename='./imgs/SolutionAufgabe2.png'))

# %% [raw]
# #create World
# size(550, 150)
#
# r = 50
# #first center
# x = r/2 + 10  # start x = abhängig von ram rechten rand
# y = 150/2 # in der mitte
#
#
# # Ellipse(linke einrückung, Einrückung von oben, elipseBreite, ellipse Höhe)
# ellipse(x,y, r, r)
#
# for i in range (0,10,1):
#     ellipse(x+i*r, y, r, r)
