# %%
from IPython.display import display, Image
display(Image(filename='./imgs/Aufgabe4.png'))

# %%
t = float(input("Alter: "))
l = float(input("Größe: "))
m = float(input("Gewicht: "))

# %%
Gm = (66.47 + 13.7 * m + 5 * l - 6.8 *t)

# %%
Gw = (665.1 + 9.6 * m + 1.8 * l - 4.7 *t)

# %%
print(Gm)
print(Gw)
