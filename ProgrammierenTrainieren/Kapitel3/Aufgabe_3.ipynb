# %%
from IPython.display import display, Image
display(Image(filename='./imgs/Aufgabe3.png'))

# %%
# m = 80
m = input("Gewicht in KG: ")
# Out:
# Gewicht in KG: 80

# %%
# ri = Verteilungsfaktor interim || r = verteilugsfaktor
# kann nochmit while Schleife fehler abfangen dass nur m oder w oder k als faktor entgegengenommen werden kann
# r = 0,7
ri = input("Manderl oder weiberl: ")
if ri == "m":
    r = 0.7
elif ri == "w":
    r = 0.6
else:
    r = 0.8
# Out:
# Manderl oder weiberl: m

# %%
# bei Bier = 0,05
Epsilon = input("Alkoholvolumenanteil in %: ")
# Out:
# Alkoholvolumenanteil in %: 0.05

# %%
# menge Volumen des Getränks
# hier 500
V = input("Volumen des Getränks in ml: ")
# Out:
# Volumen des Getränks in ml: 500

# %%
# Dichte Alkohol hier ist es 0.8
p = input("Dichte von Alkohol: ")
# Out:
# Dichte von Alkohol: 0.8

# %% [raw]
# # kontrolle
# print(V)
# print(type(V))
#
# print(Epsilon)
# print(type(Epsilon))
#
# print(p)
# print(type(p))
#
# 500
# <class 'str'>
# 0.05
# <class 'str'>
# 0.8
# <class 'str'>

# %%
A = float(V) * float(Epsilon) * float(p)
print(A)
# Out:
# 20.0

# %% [raw]
# # Kontrolle
# print(A) == 20

# %%
c = ((float(A))/((float(m))*(float(r))))
print(c)
# Out:
# 0.35714285714285715
