# %%
from IPython.display import display, Image
display(Image(filename='./imgs/Aufgabe6.png'))

# %%
import math

# %%
def calcKOF(hight,weight):
    KOF = math.sqrt((hight*weight)/3600) 
    return(KOF)

# %%
print(calcKOF(1.8, 58))
# Out:
# 0.17029386365926402
