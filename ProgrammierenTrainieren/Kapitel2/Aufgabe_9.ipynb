# %% [markdown]
# https://github.com/protrain/loesungen

# %%
from IPython.display import display, Image
display(Image(filename='./imgs/Aufgabe9.png'))

# %% [markdown]
# Ähnlich aufgabe 7 nur mit farebn diesmal & eckigen Formen
