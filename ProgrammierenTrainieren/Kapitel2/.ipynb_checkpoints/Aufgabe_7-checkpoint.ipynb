# %% [markdown]
# https://github.com/protrain/loesungen

# %%
from IPython.display import display, Image
display(Image(filename='./imgs/Aufgabe7.png'))

# %%
import turtle

# %% [markdown]
# Ist mir jetzt zu blöd / gleiche Ausgangslage wi ein Aufgabe 4
