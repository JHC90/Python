# %% [markdown]
# https://github.com/protrain/loesungen

# %%
from IPython.display import display, Image
display(Image(filename='./imgs/Aufgabe4.png'))

# %%
import turtle

# %%
def positionsetting(x,y):
    try:
        turtle.penup()
    turtle.setpos(x,y)
    try:
        turtle.pendown()
def runSquare (x,y):
    for i in range(2):
        turtle.forward(x)
        turtle.left(90)
        turtle.forward(y)
        turtle.left(90)
def runSquare (x,y):
    for i in range(2):
        turtle.forward(x)
        turtle.left(90)
        turtle.forward(y)
        turtle.left(90)

def runCircle():
    for i in range(360):
        turtle.forward(1)
        turtle.left(1)
        
def runtraianlge():
    for i in range(3):
        turtle.forward(120)
        turtle.left(120)
# Out:
#   File "<ipython-input-40-cd5f461bc3f0>", line 4
#     turtle.setpos(x,y)
#          ^
# SyntaxError: invalid syntax

# %%
positionsetting(-350,-175)
runSquare(150,400)
positionsetting(-50,-25)
runCircle()
positionsetting(100,-25)
runtraianlge()

# %%
turtle.bye()
