# %%
from IPython.display import display, Image
display(Image(filename='./imgs/Aufgabe7.png'))

# %% [markdown]
# Mach ich wieder in processing direkt

# %%
size(400,400)
background(255) # weißer hintergrund
smooth() #weichmacher 

strokeWeight(30) 
strokeCap(ROUND)

translate(width / 2, height /2)

for i in range (0,8):
    line(0,60,0,100)
    rotate(PI / 4)

# %%
display(Image(filename='./imgs/Aufgabe7Solution.png'))

# %% [markdown]
# <hr>
# <hr>
# <hr>
#
# # Here the system and packages I used for creating this Notebook

# %%
import os
import platform
print(os.name)
print(platform.system())
print(platform.release())
print("python-version: " + platform.python_version())
# Anaconda Version
# Out:
# nt
# Windows
# 10
# python-version: 3.6.9
