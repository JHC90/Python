# %%
from IPython.display import display, Image
display(Image(filename='./imgs/Aufgabe8.png'))

# %% [markdown]
# Mach ich wieder in processing direkt

# %% [markdown]
# size(400,400)
# background(255) # weißer hintergrund
# smooth() #weichmacher
#
# fill( 86 , 135 , 174 , 175 )
# noStroke()
#
# translate(width / 2 , height / 2 )
#
# radius = 175.0
#
# for i in range( 0 , 8 ):
#     arc(radius / 2 , 0.0 , radius, radius, 0 , PI)
#     rotate(PI / 4.0 )

# %%
display(Image(filename='./imgs/Aufgabe8Solution.png'))

# %% [markdown]
# <hr>
# <hr>
# <hr>
#
# # Here the system and packages I used for creating this Notebook

# %%
import os
import platform
print(os.name)
print(platform.system())
print(platform.release())
print("python-version: " + platform.python_version())
# Anaconda Version
# Out:
# nt
# Windows
# 10
# python-version: 3.6.9
