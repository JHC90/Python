# %%
from IPython.display import display, Image
display(Image(filename='./imgs/Aufgabe6.png'))

# %% [markdown]
# Für Jupyter gibt es das Packet Shapely, welche mit Geometrischen Formen hantiert, ich mach das hier grad fix im Proxessing weil ich mich nicht ins Shapely einarbeiten will
#
# Lösung
#
# * x kreise hinteinander mit unterschiedlichen radien
# * jeder Kreis eine andere Farbe

# %%
display(Image(filename='./imgs/SolutionAufgabe6.png'))

# %% [raw]
# size(800,800)
# background(255) # weißer hintergrund
# noStroke()
#
# radius = 510
#
# for c in range(255,0,-1):
#     fill(c)
#     ellipse(400,400,radius,radius)
#     radius -= 2

# %% [markdown]
# <hr>
# <hr>
# <hr>
#
# # Here the system and packages I used for creating this Notebook

# %%
import os
import platform
print(os.name)
print(platform.system())
print(platform.release())
print("python-version: " + platform.python_version())
# Anaconda Version
