# %%
from IPython.display import display, Image
display(Image(filename='./imgs/Aufgabe9.png'), )

# %%
# Hab ich aus versehen überschrieb => krieg ich aber sicher nochmals hin

# %% [markdown]
# # Invers etwas tricky, da wir im Dictionary nur von Key auf Value, aber nicht andersrum abfragen können => verusch ein revers Dict zu bauen

# %%
def buildReverseDict(incoming):
    interimReverseDict= {}
    # Hr
    for humanreadable, morseSign in morseDict.items():
        currentUpdateValue = {morseSign : humanreadable}
        interimReverseDict.update(currentUpdateValue)
    return(interimReverseDict)

# %%
reversMorseDict = buildReverseDict(morseDict)

# %%
import re
def convertToHumanReadable(incoming):
    x = re.split("\ ", incoming)
    returnValue = ""
    for i in range(0,len(x),1):
        testValue = (str(x[i]) + " ")
        if(testValue in reversMorseDict):
            returnValue = returnValue + reversMorseDict[testValue]
        else:
            pass
    return(returnValue)

# %%
convertToHumanReadable(chifre)
# Out:
# 'abcdefg'

# %%
Somit kann "chifiret" und dechifriert werden

# %% [markdown]
# <hr>
# <hr>
# <hr>
#
# # Here the system and packages I used for creating this Notebook

# %%
import os
import platform
print(os.name)
print(platform.system())
print(platform.release())
print("python-version: " + platform.python_version())
# Anaconda Version
# Out:
# nt
# Windows
# 10
# python-version: 3.6.9
