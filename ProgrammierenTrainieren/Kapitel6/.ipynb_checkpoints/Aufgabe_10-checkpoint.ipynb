# %%
from IPython.display import display, Image
display(Image(filename='./imgs/Aufgabe10.png'), )

# %%
from IPython.display import Image, display
from IPython.display import clear_output
import time

n = 6
sleeptime = 1/n

while(1 ==1):
    clear_output()
    display(Image(filename='./imgs/Animation/Hampelman1.png'))
    time.sleep(sleeptime)
    clear_output()
    display(Image(filename='./imgs/Animation/Hampelman2.png'))
    time.sleep(sleeptime)
    clear_output()
    display(Image(filename='./imgs/Animation/Hampelman3.png'))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-a4166380b0ea> in <module>
#       9     clear_output()
#      10     display(Image(filename='./imgs/Animation/Hampelman1.png'))
# ---> 11     time.sleep(sleeptime)
#      12     clear_output()
#      13     display(Image(filename='./imgs/Animation/Hampelman2.png'))
#
# KeyboardInterrupt:

# %% [markdown]
# <hr>
# <hr>
# <hr>
#
# # Here the system and packages I used for creating this Notebook

# %%
import os
import platform
print(os.name)
print(platform.system())
print(platform.release())
print("python-version: " + platform.python_version())
# Anaconda Version
# Out:
# nt
# Windows
# 10
# python-version: 3.6.9
