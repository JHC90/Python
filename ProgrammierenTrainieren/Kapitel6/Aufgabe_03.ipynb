# %%
from IPython.display import display, Image
display(Image(filename='./imgs/Aufgabe3.png'))

# %%
testwort1= "Anna"
testwort2= "reib nie ein bier"
testwort3= "Eine Horde bedrohe nie"
testwort4= "Hallo"
testwort5= "Informatik"

# %%
def returnRear(incoming):
    returnvalue = ""
    for i in range(1, len(incoming)+1,1):
        returnvalue = returnvalue + incoming[-i]
    return(returnvalue)

# %%
returnRear(testwort1)
# Out:
# 'annA'

# %%
returnRear(testwort2)
# Out:
# 'reib nie ein bier'

# %%
returnRear(testwort3)
# Out:
# 'ein ehordeb edroH eniE'

# %%
returnRear(testwort4)
# Out:
# 'ollaH'

# %%
returnRear(testwort5)
# Out:
# 'kitamrofnI'

# %% [markdown]
# <hr>
# <hr>
# <hr>
#
# # Here the system and packages I used for creating this Notebook

# %%
import os
import platform
print(os.name)
print(platform.system())
print(platform.release())
print("python-version: " + platform.python_version())
# Anaconda Version
# Out:
# nt
# Windows
# 10
# python-version: 3.6.9
