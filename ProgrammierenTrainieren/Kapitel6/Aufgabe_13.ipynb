# %%
from IPython.display import display, Image
display(Image(filename='./imgs/Aufgabe13.png'))

# %%
# Just for plotting

# %%
# for plotting the Picture
def printarray(incoming):
    LengthLevel1 = len(incoming) # nur die Anzahl der Zeilen
    LengthLevel2 = len(incoming[1]) # nur die Anzahl der spalten
    emptyString = ""
    for i in range(0, LengthLevel1,1): # Zeile
        for j in range(0, LengthLevel2,1): #Spalten
            if(incoming[i][j] == 0):
                emptyString = emptyString + "| |"
            elif(incoming[i][j] == 1):
                emptyString = emptyString + "|#|"
            elif(incoming[i][j] == 2):
                emptyString = emptyString + "|~|"
            elif(incoming[i][j] == 3):
                emptyString = emptyString + "|%|"
            elif(incoming[i][j] == 4):
                emptyString = emptyString + "|$|"
            elif(incoming[i][j] == 5):
                emptyString = emptyString + "|&|"
            else:
                pass
        emptyString = emptyString + "\n"
    print(emptyString)

# %% [markdown]
# # Testfiles

# %%
# annahme 0 bzw leer = zeigt den Green-Screen, 1 zeigt content
basicRealPic = [[1,0],
              [0,1]             
]
printarray(BasicRealBuild)
# Out:
# |#|| |
# | ||#|

# %%
basicDigitalpic = [[4,2],
                  [3,5]             
]
printarray(BasicDigitalpc)
# Out:
# |$||~|
# |%||&|

# %%
def mergePics(realPic,digitlPic):
    workingReal = realPic
    workingDig = digitlPic
    returnMatrix = []
    for i in range(0, len(workingReal),1): # iterier durch das Realbild, Zeile für Zeile
        returnRowVector = [] # wird für jede zeile erstellt und hat die summe aus real und digit value
        for j in range(0,len(workingReal[i])): # iterier durch das Realbild, für jede Zeile gehe durch jede Spalte
            if((workingReal[i][j])==1):
                returnRowVector.append(workingReal[i][j])
            else:
                returnRowVector.append(digitlPic[i][j])
        returnMatrix.append(returnRowVector)
    print(returnMatrix)
    return(returnMatrix)

# %%
mergedMatrix = mergePics(basicRealPic, basicDigitalpic)
# Out:
# [[1, 2], [3, 1]]

# %%
printarray(basicRealPic)
printarray(basicDigitalpic)
printarray(mergedMatrix)
# Out:
# |#|| |
# | ||#|
#
# |$||~|
# |%||&|
#
# |#||~|
# |%||#|

# %% [markdown]
# <hr>
# <hr>
# <hr>
#
# # Here the system and packages I used for creating this Notebook

# %%
import os
import platform
print(os.name)
print(platform.system())
print(platform.release())
print("python-version: " + platform.python_version())
# Anaconda Version
# Out:
# nt
# Windows
# 10
# python-version: 3.6.9
